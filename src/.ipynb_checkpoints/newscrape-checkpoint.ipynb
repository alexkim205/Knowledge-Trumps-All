# %%
import pandas as pd
from newspaper import Article
import newspaper

csv = "../data/west_wing_reads.csv"
df = pd.read_csv(csv)

# %%
top_10 = """
washingtonexaminer.com/politics
thehill.com
wsj.com/news/politics
washingtontimes.com/news/politics/
foxnews.com/politics.html
usatoday.com/washington/
washingtonpost.com/politics/?noredirect=on
nytimes.com/section/politics
cnn.com/politics
nbcnews.com/politics
"""

top_10_l = top_10.split()
num_of_articles = 50
publishers = []

# %%
for i, publish_link in enumerate(top_10_l):
    url = "http://" + publish_link
    paper = newspaper.build(url, memoize_articles=False)
    name = publish_link[:publish_link.rindex('.')]
    
    publisher = {}
    
    articles = paper.articles[:15]
    articlesToDict = []
    
    for content in articles:
        
        try:
            content.download()
            content.parse()
        except Exception as e:
            print(e)
            print("continuing")
            continue
            
        # Again, for consistency, if there is no found publish date the article will be skipped.
        # After 10 downloaded articles from the same newspaper without publish date, the company will be skipped.
        if content.publish_date is None:
            continue

        
        article = {}
        article['title'] = content.title
        article['link'] = content.url
        article['date_published'] = content.publish_date.isoformat()
        articlesToDict.append(article)
        print(name + ": " + content.title)
    
    publisher['name'] = name
    publisher['articles'] = articlesToDict
    publishers.append(publisher)
# Out:
# washingtonexaminer: Trump: Why are we subsidizing Saudi Arabia's military?
# washingtonexaminer: 'Corroboration needed': Kavanaugh opponents scrambled to define 'devil's triangle' before hearing
# washingtonexaminer: Trump declares rules on pre-existing illnesses 'safe,' despite Obamacare lawsuit
# washingtonexaminer: Trump mocks Dianne Feinstein for saying she didn't leak Christine Blasey Ford's letter
# washingtonexaminer: WATCH LIVE: Trump speaks at rally in West Virginia
# washingtonexaminer: Trump: FBI should find leaker in Kavanaugh investigation
# washingtonexaminer: Jeff Flake reveals George W. Bush urged him to vote for Brett Kavanaugh
# washingtonexaminer: FBI kicks off investigation into Brett Kavanaugh
# washingtonexaminer: Trump eyeing Arab ‘boots on the ground’ to counter Iran in Syria
# washingtonexaminer: Poll shows senators who vote for Kavanaugh may face midterm election trouble
# washingtonexaminer: Goodlatte: Rod Rosenstein meeting with GOP to happen 'hopefully early next week'
# washingtonexaminer: ACLU issues rare opposition statement against Brett Kavanaugh
# thehill: The Memo: GOP risks disaster with Kavanaugh, midterms
# foxnews: Trump defends Kavanaugh, derides Dems for shameful conduct: ‘Bad things will happen’ if voters stay home
# foxnews: FBI contacts 2nd Kavanaugh accuser; Trump says extra scrutiny may be 'blessing in disguise'
# foxnews: Cassidy: FBI Should Investigate Dems' Efforts to Delay Kavanaugh Confirmation
# usatoday: Corrections & Clarifications
# usatoday: FBI has contacted Deborah Ramirez about sexual assault allegations by Brett Kavanaugh
# usatoday: Behind the scenes of the Brett Kavanaugh vote: 'Someone's got to explain this to Trump'
# usatoday: Brett Kavanaugh: A week offers plenty of time for FBI to investigate allegations, former officials say
# usatoday: Mark Judge: Brett Kavanaugh's friend and potential witness, will cooperate with FBI
# usatoday: Analysis: On Kavanaugh vs. Ford, a Supreme Court showdown hinges on whom you believe
# usatoday: Court: Korean-born girl must leave US because she was adopted by her Kansas uncle a year too late
# usatoday: Tesla's Elon Musk settles SEC charges, will remain as CEO but relinquish chairman role
# usatoday: 100 years ago, influenza killed as many as 50 million people. Could it happen again today?
# usatoday: Senate panel asks FBI to investigate person who gave 'false statements' against Kavanaugh
# usatoday: Brett Kavanaugh: Looking ahead to what's next for the Supreme Court nominee
# usatoday: Taylor Swift steps out in a sheer dress for rare public outing with boyfriend Joe Alwyn
# washingtonpost: Steve Bannon thinks Michael Avenatti could be a threat to Trump in 2020. Avenatti thinks so, too.
# washingtonpost: Jeff Flake ‘flaked’: How Sean Hannity and Laura Ingraham reacted to senator’s Kavanaugh maneuver
# washingtonpost: Christine Blasey Ford spurred a woman to name her alleged rapist: a state senator, who denies it
# washingtonpost: Tesla’s Elon Musk settles with SEC, paying $20 million fine and resigning as board chairman
# washingtonpost: The ACLU typically stays neutral about Supreme Court nominees. It didn’t with Kavanaugh.
# washingtonpost: Who is Julie Swetnick, the third Kavanaugh accuser?
# washingtonpost: Christine Blasey Ford’s sisters-in-law say Kavanaugh’s testimony was confusing and ‘belligerent’
# washingtonpost: At least one senator didn’t watch the Kavanaugh hearings — because of an emergency appendectomy
# washingtonpost: Lil Wayne’s ‘Tha Carter V’ is finally out. Here’s what you need to know.
# washingtonpost: Europe holds a commanding Ryder Cup lead; pairings announced for Sunday’s singles matches
# washingtonpost: Jack Black really wants you to see his new movie. He paid for it himself.
# washingtonpost: College football winners and losers Week 5: Clemson suddenly looks vulnerable
# washingtonpost: FBI contacts second woman who has accused Brett Kavanaugh of sexual misconduct
# washingtonpost: Partisan politics and Kavanaugh’s defiant words put Supreme Court in unwelcome spotlight
# washingtonpost: In West Virginia, Trump turns Kavanaugh nomination fight into partisan rallying cry
# nytimes: Fast Favorites
# nytimes: Kavanaugh Battle Shows the Power, and the Limits, of #MeToo Movement
# nytimes: A Bitter Nominee, Questions of Neutrality, and a Damaged Supreme Court
# nytimes: Brett Kavanaugh Testimony: Three Inconsistencies the F.B.I. Investigation Could Address
# nytimes: Kavanaugh Could Help G.O.P. in Senate Midterms. But Not in House Races.
# nytimes: Washington Braces for Battle as F.B.I. Contacts Potential Witnesses to Kavanaugh Claims
# nytimes: Kavanaugh Borrows From Trump’s Playbook on White Male Anger
# nytimes: Elon Musk Resigns as Tesla Chairman in Settlement With S.E.C.
# nytimes: Housing Market Slows, as Rising Prices Outpace Wages
# nytimes: The Most Important Least-Noticed Economic Event of the Decade
# nytimes: Indonesia Tsunami and Quake Devastate an Island, Killing Hundreds
# nytimes: Sloan Kettering Executive Turns Over Windfall Stake in Biotech Start-Up
# nytimes: 11 of Our Best Weekend Reads
# nytimes: The Week in Good News: A Medical Breakthrough, a Sound Journey, Robyn
# cnn: How to Watch VR
# cnn: How Hillary Clinton's 'Murphy Brown' cameo came to be
# cnn: 'SNL' won't have to strain for material in season premiere
# cnn: Tiffany Haddish fans: Skip 'Night School,' but take 'The Oath'
# cnn: LeBron James HBO documentary 'Student Athlete' indicts NCAA
# cnn: Sophie Turner: 'Game of Thrones' viewers will be divided over show's ending
# cnn: 'God Friended Me' makes request for continued viewing
# cnn: See what's streaming in October
# cnn: 'Smallfoot' takes animated steps in the right direction
# cnn: Lil Wayne released 'Tha Carter V'
# cnn: JWoww, Roger divorce: 'Jersey Shore' star's husband vows to win her back
# cnn: The first picture of Tom Hanks as Mister Rogers is what you need today
# cnn: Rose McGowan apologizes to Asia Argento
# cnn: Lil Xan can't stay away from Flamin' Hot Cheetos

# %%
data = []
for i, publisher in enumerate(publishers):
    for a_i, article in enumerate(publisher['articles']):
        data.append(dict(zip(['name','title','link'],[publisher['name'],article['title'],article['link']])))

# %%
write_data = pd.DataFrame(data)
new_order = [1, 0, 2]
write_data = write_data[write_data.columns[new_order]]
write_data.to_csv("../data/articles.csv")
